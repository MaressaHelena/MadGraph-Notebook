# %%
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from read_lhe_uproot import *
mpl.rcParams.update(
    {'font.size': 18,
     'font.family': 'sans-serif',
     'legend.fontsize': 14,
     'axes.labelsize': 22,
     'axes.labelpad': 8.0,
     'xtick.labelsize': 14,
     'ytick.labelsize': 14
    }
    )

# %%
df = read_lhe_uproot('SM_pp_jj/Events/run_01/unweighted_events.root')
df
# Out:
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 10000
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2         Px  \
# event
# 1       21      -1       -1       -1         503         501   0.000000
# 1       21      -1       -1       -1         504         502  -0.000000
# 1       21       1        0        1         503         502  -2.361709
# 1       21       1        0        1         504         501   2.361709
# 2       21      -1       -1       -1         501         502   0.000000
# ...    ...     ...      ...      ...         ...         ...        ...
# 9999    21       1        0        1         504         502 -17.930325
# 10000    2      -1       -1       -1         502           0  -0.000000
# 10000   21      -1       -1       -1         503         502   0.000000
# 10000   21       1        0        1         503         501 -13.554645
# 10000    2       1        0        1         501           0  13.554645
#
#               Py          Pz           E    M         PT         Eta  \
# event
# 1       0.000000   63.675224   63.675224  0.0   0.000000  999.900000
# 1      -0.000000 -209.247959  209.247959  0.0   0.000000 -999.900000
# 1     -34.029980 -203.153047  205.997033  0.0  34.111834   -2.484438
# 1      34.029980   57.580312   66.926150  0.0  34.111834    1.294713
# 2       0.000000   20.538585   20.538585  0.0   0.000000  999.900000
# ...          ...         ...         ...  ...        ...         ...
# 9999  -12.543404   20.497086   29.982729  0.0  21.882265    0.835897
# 10000   0.000000  175.650324  175.650324  0.0   0.000000  999.900000
# 10000  -0.000000  -49.362613   49.362613  0.0   0.000000 -999.900000
# 10000  21.085590  -45.209446   51.693564  0.0  25.066522   -1.352177
# 10000 -21.085590  171.497157  173.319374  0.0  25.066522    2.621479
#
#             Phi    Rapidity  LifeTime  Spin  event
# event
# 1      0.000000  999.900000       0.0   1.0      1
# 1      0.000000 -999.900000       0.0   1.0      1
# 1     -1.640086   -2.484438       0.0   1.0      1
# 1      1.501507    1.294713       0.0   1.0      1
# 2      0.000000  999.900000       0.0   1.0      2
# ...         ...         ...       ...   ...    ...
# 9999  -2.531160    0.835897       0.0   1.0   9999
# 10000  0.000000  999.900000       0.0  -1.0  10000
# 10000  0.000000 -999.900000       0.0  -1.0  10000
# 10000  2.142121   -1.352177       0.0  -1.0  10000
# 10000 -0.999471    2.621479       0.0  -1.0  10000
#
# [40000 rows x 18 columns]

# %%
df['cos_theta'] = df.Pz / np.sqrt(df.Pz ** 2 + df.PT ** 2)
selection = ((df.Status == 1) & (df.PID == 21))
df_sel = df [selection]
df_sel

#pd.set_option('display.max_rows', None) # expandindo para visualização máxima do número de linhas
#df_sel # tabela específica para expandir
# Out:
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2         Px  \
# event
# 1       21       1        0        1         503         502  -2.361709
# 1       21       1        0        1         504         501   2.361709
# 2       21       1        0        1         503         502 -19.787829
# 3       21       1        0        1         503         502   8.632965
# 3       21       1        0        1         504         501  -8.632965
# ...    ...     ...      ...      ...         ...         ...        ...
# 9998    21       1        0        1         503         501  32.533056
# 9998    21       1        0        1         504         503 -32.533056
# 9999    21       1        0        1         503         501  17.930325
# 9999    21       1        0        1         504         502 -17.930325
# 10000   21       1        0        1         503         501 -13.554645
#
#               Py          Pz           E    M         PT       Eta       Phi  \
# event
# 1     -34.029980 -203.153047  205.997033  0.0  34.111834 -2.484438 -1.640086
# 1      34.029980   57.580312   66.926150  0.0  34.111834  1.294713  1.501507
# 2      16.610267   11.486010   28.273442  0.0  25.835230  0.431109  2.443274
# 3     -19.931732    4.239018   22.130778  0.0  21.721005  0.193940 -1.162062
# 3      19.931732    1.136443   21.750714  0.0  21.721005  0.052296  1.979530
# ...          ...         ...         ...  ...        ...       ...       ...
# 9998  -13.726920  -52.536277   63.299988  0.0  35.310453 -1.187999 -0.399274
# 9998   13.726920 -652.400433  653.355304  0.0  35.310453 -3.610358  2.742319
# 9999   12.543404    4.402177   22.320679  0.0  21.882265  0.199843  0.610433
# 9999  -12.543404   20.497086   29.982729  0.0  21.882265  0.835897 -2.531160
# 10000  21.085590  -45.209446   51.693564  0.0  25.066522 -1.352177  2.142121
#
#        Rapidity  LifeTime  Spin  event  cos_theta
# event
# 1     -2.484438       0.0   1.0      1  -0.986194
# 1      1.294713       0.0   1.0      1   0.860356
# 2      0.431109       0.0   1.0      2   0.406247
# 3      0.193940       0.0   1.0      3   0.191544
# 3      0.052296       0.0   1.0      3   0.052249
# ...         ...       ...   ...    ...        ...
# 9998  -1.187999       0.0   1.0   9998  -0.829957
# 9998  -3.610358       0.0  -1.0   9998  -0.998539
# 9999   0.199843       0.0   1.0   9999   0.197224
# 9999   0.835897       0.0   1.0   9999   0.683630
# 10000 -1.352177       0.0  -1.0  10000  -0.874566
#
# [15897 rows x 19 columns]

# %%
fig = plt.figure (figsize=(12,10))
plt.hist(df_sel['cos_theta'], histtype='step', bins=100)
plt.xlabel(r'$\cos\theta$')
plt.ylabel('Número de Eventos')
# Out:
# Text(0, 0.5, 'Número de Eventos')

# %%
fig = plt.figure (figsize=(12,10))
plt.hist( df_sel['Eta'], histtype='step', bins=100)
plt.xlabel(r'$\eta$')
plt.ylabel('Número de Eventos')
# Out:
# Text(0, 0.5, 'Número de Eventos')
