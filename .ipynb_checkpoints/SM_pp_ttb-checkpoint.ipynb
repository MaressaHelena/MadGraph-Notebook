# %%
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from read_lhe_uproot import *
mpl.rcParams.update(
    {'font.size': 18,
     'font.family': 'sans-serif',
     'legend.fontsize': 14,
     'axes.labelsize': 22,
     'axes.labelpad': 8.0,
     'xtick.labelsize': 14,
     'ytick.labelsize': 14
    }
    )

# %%
df = read_lhe_uproot('SM_pp_ttb/Events/run_01/unweighted_events.root')
df
# Out:
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 10000
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2         Px  \
# event
# 1       21      -1       -1       -1         501         502   0.000000
# 1       21      -1       -1       -1         502         503  -0.000000
# 1        6       1        0        1         501           0  98.049996
# 1       -6       1        0        1           0         503 -98.049996
# 2       21      -1       -1       -1         503         502   0.000000
# ...    ...     ...      ...      ...         ...         ...        ...
# 9999    -6       1        0        1           0         502  78.954117
# 10000   21      -1       -1       -1         501         502   0.000000
# 10000   21      -1       -1       -1         502         503  -0.000000
# 10000    6       1        0        1         501           0  38.506631
# 10000   -6       1        0        1           0         503 -38.506631
#
#                Py          Pz           E      M          PT         Eta  \
# event
# 1        0.000000   87.492510   87.492510    0.0    0.000000  999.900000
# 1       -0.000000 -502.387568  502.387568    0.0    0.000000 -999.900000
# 1       49.015261 -144.379269  250.580667  173.0  109.618874   -1.088836
# 1      -49.015261 -270.515790  339.299410  173.0  109.618874   -1.635200
# 2        0.000000   49.422450   49.422450    0.0    0.000000  999.900000
# ...           ...         ...         ...    ...         ...         ...
# 9999    43.617212  -83.059326  212.047319  173.0   90.200963   -0.824266
# 10000    0.000000  359.546960  359.546960    0.0    0.000000  999.900000
# 10000   -0.000000 -234.431220  234.431220    0.0    0.000000 -999.900000
# 10000  218.210958  136.757103  312.618438  173.0  221.582451    0.583504
# 10000 -218.210958  -11.641363  281.359742  173.0  221.582451   -0.052513
#
#             Phi    Rapidity  LifeTime  Spin  event
# event
# 1      0.000000  999.900000       0.0  -1.0      1
# 1      0.000000 -999.900000       0.0   1.0      1
# 1      0.463568   -0.656724       0.0  -1.0      1
# 1     -2.678024   -1.091095       0.0   1.0      1
# 2      0.000000  999.900000       0.0  -1.0      2
# ...         ...         ...       ...   ...    ...
# 9999   0.504713   -0.413809       0.0   1.0   9999
# 10000  0.000000  999.900000       0.0  -1.0  10000
# 10000  0.000000 -999.900000       0.0  -1.0  10000
# 10000  1.396129    0.469082       0.0  -1.0  10000
# 10000 -1.745463   -0.041399       0.0  -1.0  10000
#
# [40000 rows x 18 columns]

# %%
df['cos_theta'] = df.Pz / np.sqrt(df.Pz ** 2 + df.PT ** 2)
selection = ((df.Status == 1) & (df.PID == 6))
df_sel = df [selection]
df_sel
#pd.set_option('display.max_rows', None) # expandindo para visualização máxima do número de linhas
#df_sel # tabela específica para expandir
# Out:
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2          Px  \
# event
# 1        6       1        0        1         501           0   98.049996
# 2        6       1        0        1         501           0  -91.667626
# 3        6       1        0        1         502           0   41.895768
# 4        6       1        0        1         501           0  -51.418187
# 5        6       1        0        1         501           0   46.321120
# ...    ...     ...      ...      ...         ...         ...         ...
# 9996     6       1        0        1         501           0 -121.230707
# 9997     6       1        0        1         501           0  163.725467
# 9998     6       1        0        1         502           0  -89.272877
# 9999     6       1        0        1         501           0  -78.954117
# 10000    6       1        0        1         501           0   38.506631
#
#                Py           Pz            E      M          PT       Eta  \
# event
# 1       49.015261  -144.379269   250.580667  173.0  109.618874 -1.088836
# 2       32.544320  -232.657339   305.811255  173.0   97.273256 -1.606276
# 3       99.897580   119.782104   236.667561  173.0  108.327198  0.954205
# 4     -110.497869  -957.916297   981.012865  173.0  121.875383 -2.758931
# 5      106.565700  -707.106414   737.177302  173.0  116.197653 -2.505719
# ...           ...          ...          ...    ...         ...       ...
# 9996  -155.784270 -1079.786280  1111.230414  173.0  197.397120 -2.400700
# 9997   -28.745804   830.195331   864.167598  173.0  166.229811  2.311313
# 9998   -56.643993   259.972971   329.686418  173.0  105.726952  1.631861
# 9999   -43.617212  -582.808969   614.598656  173.0   90.200963 -2.564902
# 10000  218.210958   136.757103   312.618438  173.0  221.582451  0.583504
#
#             Phi  Rapidity  LifeTime  Spin  event  cos_theta
# event
# 1      0.463568 -0.656724       0.0  -1.0      1  -0.796453
# 2      2.800448 -0.998082       0.0  -1.0      2  -0.922608
# 3      1.173689  0.557499       0.0   1.0      3   0.741681
# 4     -2.006327 -2.215104       0.0   1.0      4  -0.992003
# 5      1.160762 -1.935906       0.0  -1.0      5  -0.986766
# ...         ...       ...       ...   ...    ...        ...
# 9996  -2.232100 -2.121954       0.0   1.0   9996  -0.983698
# 9997  -0.173802  1.954759       0.0  -1.0   9997   0.980537
# 9998  -2.576188  1.067576       0.0   1.0   9998   0.926326
# 9999  -2.636880 -1.814386       0.0   1.0   9999  -0.988234
# 10000  1.396129  0.469082       0.0  -1.0  10000   0.525208
#
# [10000 rows x 19 columns]

# %%
fig = plt.figure (figsize=(12,10))
plt.hist(df_sel['cos_theta'], histtype='step', bins=100)
plt.xlabel(r'$\cos\theta$')
plt.ylabel('Número de Eventos')
# Out:
# Text(0, 0.5, 'Número de Eventos')

# %%
fig = plt.figure (figsize=(12,10))
plt.hist( df_sel['Eta'], histtype='step', bins=100)
plt.xlabel(r'$\eta$')
plt.ylabel('Número de Eventos')
# Out:
# Text(0, 0.5, 'Número de Eventos')
